# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

# %%
df_10k = pd.read_csv('D:\Google Drive\Current\Capstone\clean_filings\sec_10K.csv')

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

# %%
# calculate tfidf
vectorizer = TfidfVectorizer(stop_words='english', ngram_range=(2,2), min_df=round(len(df_10k['text'])/20)+1)
X = vectorizer.fit_transform(df_10k['text'])
top_keywords_all = []

for i in range(len(df_10k['text'])):
    keywords = {}
    tfidf = X[i,:].toarray().tolist()[0]

    # sort top keywords
    for word, count in zip(vectorizer.get_feature_names(), tfidf):
        keywords[word] = count
    top_keywords = [x[0] for x in sorted(keywords.items(), key=lambda item: item[1], reverse=True)][:100]
    top_keywords_all.append(top_keywords)

df['keywords'] = top_keywords_all

# %%
top_keywords_all
# Out:
# [['james financial',
#   '30 2020',
#   'september 30',
#   'financial subsidiaries',
#   'covid 19',
#   'ended september',
#   '19 pandemic',
#   'fair value',
#   '2020 2019',
#   'subsidiaries notes',
#   'raymond james',
#   'residential mortgage',
#   'consolidated financial',
#   'asset management',
#   'subsidiaries management',
#   'loan losses',
#   'loans held',
#   'year ended',
#   'financial condition',
#   'notes consolidated',
#   'private equity',
#   'financial advisors',
#   '30 2019',
#   'allowance loan',
#   'loan portfolio',
#   'statements form',
#   'tax exempt',
#   'party banks',
#   'senior notes',
#   'financial statements',
#   'consolidated statements',
#   'form 10',
#   'related administrative',
#   'following table',
#   'based accounts',
#   '2012 stock',
#   'net income',
#   'segregated pursuant',
#   'statements financial',
#   'sale securities',
#   'available sale',
#   'million september',
#   'brokerage revenues',
#   'fee based',
# ...
